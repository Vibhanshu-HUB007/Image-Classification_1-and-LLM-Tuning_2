# %%
# In your Jupyter notebook
exec(open('test_model.py').read())
# Out:
# 🧪 Time Extraction Model Test
# ...
# 📁 Model path: --f=/run/user/1000/jupyter/runtime/kernel-v31f16827e074edc287ac5ea6c56a7f75479bb9891.json
# 🖥️ Device: CUDA
#
# 🔄 Loading model from: --f=/run/user/1000/jupyter/runtime/kernel-v31f16827e074edc287ac5ea6c56a7f75479bb9891.json
# 📍 Using device: cuda
# ❌ Model path does not exist: --f=/run/user/1000/jupyter/runtime/kernel-v31f16827e074edc287ac5ea6c56a7f75479bb9891.json
# ⚠️ Model loading failed, will use rule-based extraction only
#
# 🔍 Testing Time Extraction:
# ----------------------------------------
#
# 🔍 Processing query: 'show me yesterday at 3pm'
# 🔄 Using rule-based fallback...
#
# 1. Query: 'show me yesterday at 3pm'
#    ✅ Start: 2025-08-03T15:00:00
#    🔄 Range: False
#    📊 Confidence: 0.80
#    🛠️ Method: Fallback extraction
#
# 🔍 Processing query: 'what happened this morning at 9:30?'
# 🔄 Using rule-based fallback...
#
# 2. Query: 'what happened this morning at 9:30?'
#    ✅ Start: 2025-08-04T09:30:00
#    🔄 Range: False
# ...
